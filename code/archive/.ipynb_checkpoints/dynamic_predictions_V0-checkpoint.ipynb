# %%
import requests 
import datetime as dt 
import json
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from datetime import datetime

import torch 
import torch.nn as nn 
from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import mean_squared_error

from tensorflow import keras
from keras.models import Sequential 
from keras.layers import Dense
from keras.layers import LSTM 
from tensorflow.keras import activations
from tensorflow.keras import layers


import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-09-26 19:26:54.175886: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#snowbird 
#USS0011J42S  40.5600 -111.6600 2938.3 UT Snowbird  
#park city 
#US1UTSM0007  40.7455 -111.6095 2083.3 UT PARK CITY 8.7 NW

# %% [markdown]
# ### Data Variable Dictionary
#
# * tavg = average temperature
# * tmax = max temp
# * tmin = min temp
# * tobs = temperature at time of observation
# * snow = inches snowed that day --> this will be our outcome variable
# * prcp = precipitation (measured in inches)
# * snwd = snow depth
# * wesd = water equivalent of snow on ground (depth of water that would cover the ground if snow was liquid)

# %%
#Quick visualiztion 
def read_in_data():
    return pd.read_csv('../data/alta.csv')
data = read_in_data()

# %%
def make_quick_viz():
    df = data[['DATE', 'PRCP', 
               'TMAX', 'TMIN', 'SNOW']]
    
    plt.title("Histogram of Daily Snow Fall Totals Inches")
    plt.hist(data['SNOW'])
    plt.show()
    print(" ")
    plt.title("Correlation between Snow, Precipitaiton, Max Temp, Min Temp")
    df_corr = df[['PRCP', 'SNOW', 
               'TMAX', 'TMIN']].corr()
    sns.heatmap(df_corr)
    plt.show()
    
    return df

# %%
data2 = make_quick_viz()

# %% [markdown]
# As is the case with time series data, and as expected, there is a lot of cereal auto-correlation going on here. That presents some unique challenges when modeling because it essential means that we do not have any purely unique observations, we have like 5k observations, but none of those are truely independent except for perhasp the first. We will need to use non-linear methods to approximate this

# %%
#incase i run on colab and want to use a GPU 
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
def convert_to_datetime(df):
    
    df['DATE'] = pd.to_datetime(df['DATE'])
    plt.title("Time Series of Snow Fall")
    plt.ylabel("Inches of Snow")
    plt.xlabel("Year")
    plt.plot(df['DATE'], df['SNOW'])
    plt.show()
    return df 
df = convert_to_datetime(data)

# %%
data2.isnull().sum()
# Out:
# DATE      0
# PRCP    105
# TMAX    135
# TMIN    164
# SNOW    213
# dtype: int64

# %%
#got to view this null data 

n_df = data2.isnull().any(axis = 1)
null_rows = data2[n_df]

# %%
426/len(data2)
# Out:
# 0.07422895974908521

# %%
def clean_null(df):
    
    
    df['DATE'] = pd.to_datetime(data2['DATE'])
    df['month'] = df['DATE'].apply(lambda x: x.month)
    df['day'] = df['DATE'].apply(lambda x: x.day)
    

    for col in df.columns.tolist():
        for i in range(len(df[col])):
            if str(df[col][i]) == 'nan':
                #subset = data2[(data2['month'] == 10) &(data2['day']==25)]
            
                df[col][i] = df[(df['month'] ==df['month'][i])&(df['day']==df['day'][i])][col].median()
            
            
    df = df.drop(columns = ['month', 'day'])       
    return df

# %%
data3 = clean_null(data2)

# %%
## Dont need to lag!

# %%
def create_LSTM_data(df):
    
    #creating a copy
    df2 = df.copy()
    #setting index 
    df2.set_index("DATE", inplace = True)
    n_steps = [1]
    
    for col in df2.columns.tolist():
        for i in n_steps:
            df2[f'{col}_t_{i}'] = df2[col].shift(i)
    
    df2.dropna(inplace = True)
    #df2['output'] = df2.apply(lambda x: np.array([x['PRCP'], x['TMAX'], x['TMIN'], x['SNOW']]), axis = 1)
    return df2

# %%
data4 = create_LSTM_data(data3)
data4.head(3)
# Out:
#             PRCP  TMAX  TMIN  SNOW  PRCP_t_1  TMAX_t_1  TMIN_t_1  SNOW_t_1
# DATE
# 2007-09-20  0.00  65.0  39.0   0.0       0.0      64.0      41.0       0.0
# 2007-09-21  0.00  66.0  43.0   0.0       0.0      65.0      39.0       0.0
# 2007-09-22  0.37  60.0  46.0   0.0       0.0      66.0      43.0       0.0

# %%
def get_data_organized(df):
    #df.set_index("DATE", inplace = True)
    #snow = df['SNOW']
    #df['output'] = df.apply(lambda x: np.array([x['PRCP'], x['TMAX'], x["TMIN"], x["SNOW"]]), axis = 1)
    #df2 = df.drop(columns = ['SNOW', 'TMAX', 'TMIN', 'PRCP'])
    
    #df2['SNOW'] = snow
    
    return df

# %%
data5 = get_data_organized(data4)

# %%
data5
# Out:
#             PRCP  TMAX  TMIN  SNOW  PRCP_t_1  TMAX_t_1  TMIN_t_1  SNOW_t_1
# DATE
# 2007-09-20  0.00  65.0  39.0   0.0      0.00      64.0      41.0       0.0
# 2007-09-21  0.00  66.0  43.0   0.0      0.00      65.0      39.0       0.0
# 2007-09-22  0.37  60.0  46.0   0.0      0.00      66.0      43.0       0.0
# 2007-09-23  0.50  49.0  37.0   0.1      0.37      60.0      46.0       0.0
# 2007-09-24  0.90  37.0  23.0   5.5      0.50      49.0      37.0       0.1
# ...          ...   ...   ...   ...       ...       ...       ...       ...
# 2023-09-14  0.01  58.0  38.0   0.0      0.14      56.0      42.0       0.0
# 2023-09-15  0.00  60.0  39.0   0.0      0.01      58.0      38.0       0.0
# 2023-09-16  0.00  62.0  40.0   0.0      0.00      60.0      39.0       0.0
# 2023-09-17  0.00  64.0  43.0   0.0      0.00      62.0      40.0       0.0
# 2023-09-18  0.00  64.0  45.0   0.0      0.00      64.0      43.0       0.0
#
# [5738 rows x 8 columns]

# %%
def scale_data(df):
    scaler = MinMaxScaler(feature_range = (-1,1))
    scaled_df = scaler.fit_transform(df)
    #df['output'] = df.apply(lambda x: np.array([x['PRCP'], x['TMAX'], x['TMIN'], x['SNOW']]), axis = 1)
    return scaled_df, scaler

# %%
scaled_data, total_scaler = scale_data(data5)

# %%
def create_output(matrix):
    scaled_df = pd.DataFrame(data = matrix, 
                columns = ['PRCP', 'TMAX', 'TMIN',
                          'SNOW', 'PRCP_t_1', 'TMAX_t_1', 'TMIN_t_1', 'SNOW_t_1'])

    scaled_df['output'] = scaled_df.apply(lambda x: np.array([x['PRCP'],#.astype(np.float32),
                                                              x['TMAX'],#.astype(np.float32), 
                                                              x['TMIN'],#.astype(np.float32), 
                                                              x['SNOW']],#.astype(np.float32)]
                                                               ), axis = 1)
    scaled_df['output'] = scaled_df['output']
    scaled_df = scaled_df.drop(columns = ['PRCP', 'TMAX', 'TMIN',
                          'SNOW'])
    return scaled_df

# %%
scaled_df = create_output(scaled_data)

# %%
scaled_df
# Out:
#       PRCP_t_1  TMAX_t_1  TMIN_t_1  SNOW_t_1  \
# 0    -1.000000  0.536585  0.407407  -1.00000
# 1    -1.000000  0.560976  0.358025  -1.00000
# 2    -1.000000  0.585366  0.456790  -1.00000
# 3    -0.831818  0.439024  0.530864  -1.00000
# 4    -0.772727  0.170732  0.308642  -0.99375
# ...        ...       ...       ...       ...
# 5733 -0.936364  0.341463  0.432099  -1.00000
# 5734 -0.995455  0.390244  0.333333  -1.00000
# 5735 -1.000000  0.439024  0.358025  -1.00000
# 5736 -1.000000  0.487805  0.382716  -1.00000
# 5737 -1.000000  0.536585  0.456790  -1.00000
#
#                                                  output
# 0     [-1.0, 0.5609756097560976, 0.3580246913580246,...
# 1     [-1.0, 0.5853658536585367, 0.45679012345678993...
# 2     [-0.8318181818181818, 0.4390243902439024, 0.53...
# 3     [-0.7727272727272727, 0.1707317073170731, 0.30...
# 4     [-0.5909090909090909, -0.12195121951219512, -0...
# ...                                                 ...
# 5733  [-0.9954545454545455, 0.3902439024390245, 0.33...
# 5734  [-1.0, 0.4390243902439024, 0.3580246913580246,...
# 5735  [-1.0, 0.4878048780487805, 0.382716049382716, ...
# 5736  [-1.0, 0.5365853658536586, 0.45679012345678993...
# 5737  [-1.0, 0.5365853658536586, 0.5061728395061729,...
#
# [5738 rows x 5 columns]

# %%
#scaled_y, scaler_y = scale_data(data5[['SNOW']])

# %%
#scaled_df_x, scaler_x = scale_data(data5[['PRCP', "TMAX", "TMIN"]])

# %%
data5.loc['2007-01-01':'2022-09-27']
# Out:
#             PRCP  TMAX  TMIN  SNOW  PRCP_t_1  TMAX_t_1  TMIN_t_1  SNOW_t_1
# DATE
# 2007-09-20  0.00  65.0  39.0   0.0      0.00      64.0      41.0       0.0
# 2007-09-21  0.00  66.0  43.0   0.0      0.00      65.0      39.0       0.0
# 2007-09-22  0.37  60.0  46.0   0.0      0.00      66.0      43.0       0.0
# 2007-09-23  0.50  49.0  37.0   0.1      0.37      60.0      46.0       0.0
# 2007-09-24  0.90  37.0  23.0   5.5      0.50      49.0      37.0       0.1
# ...          ...   ...   ...   ...       ...       ...       ...       ...
# 2022-09-23  0.00  56.0  33.0   0.0      0.01      55.0      45.0       0.0
# 2022-09-24  0.00  59.0  34.0   0.0      0.00      56.0      33.0       0.0
# 2022-09-25  0.00  62.0  39.0   0.0      0.00      59.0      34.0       0.0
# 2022-09-26  0.00  64.0  43.0   0.0      0.00      62.0      39.0       0.0
# 2022-09-27  0.00  67.0  42.0   0.0      0.00      64.0      43.0       0.0
#
# [5382 rows x 8 columns]

# %%
# train_x = X[-5376:,]
# test_x = X[5376:, ]
# train_y = y[-5376:,]
# test_y = y[5376:, ]

# %%
scaled_df
# Out:
#       PRCP_t_1  TMAX_t_1  TMIN_t_1  SNOW_t_1  \
# 0    -1.000000  0.536585  0.407407  -1.00000
# 1    -1.000000  0.560976  0.358025  -1.00000
# 2    -1.000000  0.585366  0.456790  -1.00000
# 3    -0.831818  0.439024  0.530864  -1.00000
# 4    -0.772727  0.170732  0.308642  -0.99375
# ...        ...       ...       ...       ...
# 5733 -0.936364  0.341463  0.432099  -1.00000
# 5734 -0.995455  0.390244  0.333333  -1.00000
# 5735 -1.000000  0.439024  0.358025  -1.00000
# 5736 -1.000000  0.487805  0.382716  -1.00000
# 5737 -1.000000  0.536585  0.456790  -1.00000
#
#                                                  output
# 0     [-1.0, 0.5609756097560976, 0.3580246913580246,...
# 1     [-1.0, 0.5853658536585367, 0.45679012345678993...
# 2     [-0.8318181818181818, 0.4390243902439024, 0.53...
# 3     [-0.7727272727272727, 0.1707317073170731, 0.30...
# 4     [-0.5909090909090909, -0.12195121951219512, -0...
# ...                                                 ...
# 5733  [-0.9954545454545455, 0.3902439024390245, 0.33...
# 5734  [-1.0, 0.4390243902439024, 0.3580246913580246,...
# 5735  [-1.0, 0.4878048780487805, 0.382716049382716, ...
# 5736  [-1.0, 0.5365853658536586, 0.45679012345678993...
# 5737  [-1.0, 0.5365853658536586, 0.5061728395061729,...
#
# [5738 rows x 5 columns]

# %%
# split a multivariate sequence into samples
def split_sequences(sequences, n_steps_in, n_steps_out):
    #X, y = list(), list()
    X = list() 
    for i in range(len(sequences)):
    # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out-1
    # check if we are beyond the dataset

        if out_end_ix > len(sequences):
            print(i)
            break
    # gather input and output parts of the pattern
        #seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1:out_end_ix, -1]
        seq_x = sequences[i:end_ix, :-1]#, sequences[end_ix-1:out_end_ix, -1]
        X.append(seq_x)
        #y.append(seq_y)
    return np.array(X)#, np.array(y)

# %%
look_back = 7
predict = 1

# %%
print(np.array(scaled_df)[0])
np.array(scaled_df)[0][-1:]
# Out:
# [-1.0 0.5365853658536586 0.40740740740740744 -1.0
#  array([-1.        ,  0.56097561,  0.35802469, -1.        ])]
# array([array([-1.        ,  0.56097561,  0.35802469, -1.        ])],
#       dtype=object)

# %%
def split_series(series, n_past, n_future):
  #
  # n_past ==> no of past observations
  #
  # n_future ==> no of future observations 
  #
    X, y = list(), list()
    for window_start in range(len(series)):
        
        past_end = window_start + n_past
        future_end = past_end + n_future
        #print(series[window_start][-1:])
        if future_end > len(series):
            break
        # slicing the past and future parts of the window
        #print("here")
        past, future = series[window_start:past_end, :-1], series[window_start][-1:]
        
        X.append(past)
        y.append(future)
    return np.array(X), np.array(y)

# %%
seq_x, seq_y = split_series(np.array(scaled_df), look_back, predict)

# %%
seq_x[0][0]
# Out:
# array([-1.0, 0.5365853658536586, 0.40740740740740744, -1.0], dtype=object)

# %%
seq_y[0][0]
# Out:
# array([-1.        ,  0.56097561,  0.35802469, -1.        ])

# %%
y2 = list()
for i in range(len(seq_y)):
    y2.append(seq_y[i][0])
y2 = np.array(y2)

# %%
seq_x[500]
# Out:
# array([[-1.0, 0.0, 0.012345679012345623, -1.0],
#        [-0.8, -0.14634146341463417, -0.012345679012345734, -0.5625],
#        [-0.95, -0.31707317073170727, -0.16049382716049387, -0.875],
#        [-1.0, -0.2682926829268293, -0.0864197530864198, -1.0],
#        [-0.25909090909090915, -0.41463414634146345, -0.18518518518518523,
#         -0.0625],
#        [-0.8318181818181818, -0.5609756097560976, -0.33333333333333337,
#         -0.5],
#        [-0.9318181818181819, -0.4878048780487805, -0.5308641975308642,
#         -0.75]], dtype=object)

# %%
train_x = seq_x[-5376:,]
test_x = seq_x[5376:, ]
train_y = y2[-5376:,]
test_y = y2[5376:, ]

# %%
print(len(train_x))
print(len(train_y))
print(len(test_x))
print(len(test_y))


print(type(train_x))
print(type(train_y))
print(type(test_x))
print(type(test_y))
# Out:
# 5376
# 5376
# 355
# 355
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
train_x=np.asarray(train_x).astype(float)

train_y=np.asarray(train_y).astype(float)


test_x=np.asarray(test_x).astype(float)

test_y=np.asarray(test_y).astype(float)

# %%
n_features = train_x[0].shape[1]

# %%
n_features
# Out:
# 4

# %% [markdown]
# ### Build deep learning model

# %%
opt = keras.optimizers.Adam(learning_rate = 0.0001)

# %%
print(train_x[0])
print(" ")
print(train_y[0])
print(" ")
print(test_x[0])
print(" ")
print(test_y[0])
# Out:
# [[-1.          0.29268293  0.43209877 -1.        ]
#  [-1.          0.29268293  0.28395062 -1.        ]
#  [-1.          0.31707317  0.18518519 -1.        ]
#  [-1.          0.46341463  0.18518519 -1.        ]
#  [-1.          0.51219512  0.33333333 -1.        ]
#  [-1.          0.48780488  0.43209877 -1.        ]
#  [-1.          0.63414634  0.48148148 -1.        ]]
#
# [-1.          0.29268293  0.28395062 -1.        ]
#
# [[-0.97727273  0.53658537  0.50617284 -1.        ]
#  [-0.99545455  0.31707317  0.50617284 -1.        ]
#  [-1.          0.34146341  0.20987654 -1.        ]
#  [-1.          0.41463415  0.2345679  -1.        ]
#  [-1.          0.48780488  0.35802469 -1.        ]
#  [-1.          0.53658537  0.45679012 -1.        ]
#  [-1.          0.6097561   0.43209877 -1.        ]]
#
# [-0.99545455  0.31707317  0.50617284 -1.        ]

# %%
from keras.layers import LSTM, Dense, Dropout

# %%
model = Sequential()
model.add(LSTM(32, input_shape = (look_back, n_features),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64))
model.add(Dropout(0.2))
model.add(Dense(4, activation='relu'))
model.compile(loss='mse', optimizer='adam')

model.fit(train_x,train_y,batch_size=30, epochs=48)

#predict on unseen data, expects tensors of shape (None, number_of_notes_per_song-1, data_dim)
# Out:
# Epoch 1/48
# 180/180 [==============================] - 5s 8ms/step - loss: 0.4805
# Epoch 2/48
# 180/180 [==============================] - 1s 8ms/step - loss: 0.4732
# Epoch 3/48
# 180/180 [==============================] - 1s 8ms/step - loss: 0.4725
# Epoch 4/48
# 180/180 [==============================] - 1s 8ms/step - loss: 0.4720
# Epoch 5/48
# 180/180 [==============================] - 1s 8ms/step - loss: 0.4716
# Epoch 6/48
# 180/180 [==============================] - 1s 7ms/step - loss: 0.4715
# Epoch 7/48
# 180/180 [==============================] - 1s 7ms/step - loss: 0.4713
# Epoch 8/48
# 180/180 [==============================] - 1s 7ms/step - loss: 0.4713
# Epoch 9/48
# 180/180 [==============================] - 1s 8ms/step - loss: 0.4712
# Epoch 10/48
# 180/180 [==============================] - 1s 8ms/step - loss: 0.4712
# Epoch 11/48
# 180/180 [==============================] - 1s 8ms/step - loss: 0.4711
# Epoch 12/48
# 180/180 [==============================] - 1s 7ms/step - loss: 0.4711
# Epoch 13/48
# 180/180 [==============================] - 1s 8ms/step - loss: 0.4711
# Epoch 14/48
# 180/180 [==============================] - 1s 7ms/step - loss: 0.4710
# Epoch 15/48
# 180/180 [==============================] - 1s 7ms/step - loss: 0.4709
# Epoch 16/48
# 180/180 [==============================] - 1s 8ms/step - loss: 0.4709
# Epoch 17/48
# 180/180 [==============================] - 1s 8ms/step - loss: 0.4709
# Epoch 18/48
# 180/180 [==============================] - 1s 8ms/step - loss: 0.4707
# Epoch 19/48
#  14/180 [=>............................] - ETA: 1s - loss: 0.4757

# %%
model.predict(test_x)[0]
# Out:
# 12/12 [==============================] - 1s 3ms/step
# array([0.        , 0.42408916, 0.37267   , 0.        ], dtype=float32)

# %%
# model = Sequential()
# model.add(LSTM(50, layers.Activation(activations.relu), return_sequences = True, input_shape = (look_back, n_features)))
# model.add(Dropout(0.2))
# model.add(LSTM(50, layers.Activation(activations.relu)))
# model.add(Dense(3, predict))
# model.add(layers.Activation(activations.relu))
# model.compile(loss = 'mse', optimizer = opt, )

# %%
# history = model.fit(train_x,
#                     train_y,
#                     epochs = 1000, steps_per_epoch = 25, verbose = 1, validation_data = (test_x, 
#                                                                                          test_y), 
#                     shuffle = False)

# %%
print("Done training")
# Out:
# Done training

# %%
y_pred = model.predict(test_x)
# Out:
# 12/12 [==============================] - 1s 3ms/step

# %%
y_pred_inv = scaler_y.inverse_transform(y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 y_pred_inv = scaler_y.inverse_transform(y_pred)
#
# NameError: name 'scaler_y' is not defined

# %%
y_pred[0]
# Out:
# array([0.], dtype=float32)

# %%
sum(np.abs(y_pred_inv))

# %%
plt.plot(np.abs(y_pred_inv))

# %%
y

# %%
y_pred_inv

# %%
def make_new_preds():
    import datetime
    last_pred = data5.tail(7)
    new_date = last_pred.tail(1).index.date 
    dates = []
    dates.append(new_date[0])
    while new_date <= datetime.date(2024, 5, 31):
        new_date += datetime.timedelta(days=1)
        
        dates.append(new_date[0])
    return dates

# %%
import datetime

(data5.tail(7).tail(1).index + pd.DateOffset(1)).date < datetime.date(2024, 5, 31)

# %%
import datetime
datetime.date(2024, 5, 31)
